# %% [markdown]
# ### File to test the functions on the data that we have until now:

# %% [markdown]
# ##### To Do:
#
# - find a way to make an exception/fix for FP1 when there is no clear IC -> AND OTHER BUGS (e.g. not complete forcesets) !!
# - be able to compare between trials -> do we need that?
# - make butterworth filter accordingly -> sampling frequency + cut-ff => discuss with Amelie
# - below threshold = 0 also for Fx and Fy?
# - boxplot function?
# - fix easier path names to make it work all the time

# %%
import os
import sys
sys.path.insert(0, os.path.dirname(os.path.dirname(os.getcwd())))
from Base.GRF_analysis_code import analyze_folder_segm, analyze_folder_stats, segm_plot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Directory = os.getcwd()
print(Directory)
# Out:
# /Users/ernstdavidts/Library/CloudStorage/OneDrive-UGent/Master I/Oslo/Curved_Running_Pilot/Base/tests
# /Users/ernstdavidts/Library/CloudStorage/OneDrive-UGent/Master I/Oslo/Curved_Running_Pilot/Base/tests

# %%
folder = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), "files", "Straight")

df_segm = analyze_folder_segm(folder)
df = analyze_folder_stats(folder)

df['group'] =  df["Participant"] + '_' + df['shoe'].astype(str) # Nieuwe kolom voor groep
df.boxplot(column="max_Fz", by="group", figsize=(10, 6))  # Één grafiek met alle groepen
plt.title("Max Fz per Plate en Shoe")
plt.xticks(rotation=45, ha='right')
plt.show()

df.boxplot(column="max_Fx", by="group")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
segm_plot(df_segm, force= "Fx", participant="01", plate= "FP2", type= "normalised")
